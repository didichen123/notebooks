# %%
#https://pandas.pydata.org/pandas-docs/stable/io.html
import pandas as pd

dfs = pd.read_csv("ted_main.csv", encoding = "utf-8")
print(dfs)
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1          265  With the same humor and humanity he exuded in ...       977
# 2          124  New York Times columnist David Pogue takes aim...      1286
# 3          200  In an emotionally charged talk, MacArthur-winn...      1116
# 4          593  You've never seen data presented like this. Wi...      1190
# 5          672  Tony Robbins discusses the "invisible forces" ...      1305
# 6          919  When two young Mormon missionaries knock on Ju...       992
# 7           46  Architect Joshua Prince-Ramus takes the audien...      1198
# 8          852  Philosopher Dan Dennett calls for religion -- ...      1485
# 9          900  Pastor Rick Warren, author of "The Purpose-Dri...      1262
# 10          79  Accepting his 2006 TED Prize, Cameron Sinclair...      1414
# ...

# %%
dfs   ##使用 pandas jupyter notebook 可自己出現表格
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1          265  With the same humor and humanity he exuded in ...       977
# 2          124  New York Times columnist David Pogue takes aim...      1286
# 3          200  In an emotionally charged talk, MacArthur-winn...      1116
# 4          593  You've never seen data presented like this. Wi...      1190
# 5          672  Tony Robbins discusses the "invisible forces" ...      1305
# 6          919  When two young Mormon missionaries knock on Ju...       992
# 7           46  Architect Joshua Prince-Ramus takes the audien...      1198
# 8          852  Philosopher Dan Dennett calls for religion -- ...      1485
# 9          900  Pastor Rick Warren, author of "The Purpose-Dri...      1262
# 10          79  Accepting his 2006 TED Prize, Cameron Sinclair...      1414
# ...

# %%
dfs["comments"]  ##印出行
# Out:
# 0       4553
# 1        265
# 2        124
# 3        200
# 4        593
# 5        672
# 6        919
# 7         46
# 8        852
# 9        900
# 10        79
# 11        55
# 12        71
# 13       242
# 14        99
# 15       325
# 16       305
# 17        88
# 18       163
# 19        84
# 20       108
# 21       185
# 22        50
# 23       556
# 24       117
# 25       184
# 26       507
# 27        95
# 28       355
# 29       970
#         ...
# 2520      81
# 2521      13
# 2522      12
# 2523      20
# 2524       9
# 2525      18
# 2526      39
# 2527      17
# 2528       3
# 2529      45
# 2530      12
# 2531      18
# 2532      25
# 2533       9
# 2534       2
# 2535       8
# 2536      21
# 2537      39
# 2538       7
# 2539      10
# 2540      33
# 2541      12
# 2542       3
# 2543       7
# 2544      10
# 2545      17
# 2546       6
# 2547      10
# 2548      32
# 2549       8
# Name: comments, Length: 2550, dtype: int64

# %%
dfs[["comments","description"]]  ##印出行
# Out:
#       comments                                        description
# 0         4553  Sir Ken Robinson makes an entertaining and pro...
# 1          265  With the same humor and humanity he exuded in ...
# 2          124  New York Times columnist David Pogue takes aim...
# 3          200  In an emotionally charged talk, MacArthur-winn...
# 4          593  You've never seen data presented like this. Wi...
# 5          672  Tony Robbins discusses the "invisible forces" ...
# 6          919  When two young Mormon missionaries knock on Ju...
# 7           46  Architect Joshua Prince-Ramus takes the audien...
# 8          852  Philosopher Dan Dennett calls for religion -- ...
# 9          900  Pastor Rick Warren, author of "The Purpose-Dri...
# 10          79  Accepting his 2006 TED Prize, Cameron Sinclair...
# 11          55  Jehane Noujaim unveils her 2006 TED Prize wish...
# 12          71  Accepting the 2006 TED Prize, Dr. Larry Brilli...
# ...

# %%
del dfs["published_date"]   ##刪除published_date行   (蹤向)

# %%
dfs
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1          265  With the same humor and humanity he exuded in ...       977
# 2          124  New York Times columnist David Pogue takes aim...      1286
# 3          200  In an emotionally charged talk, MacArthur-winn...      1116
# 4          593  You've never seen data presented like this. Wi...      1190
# 5          672  Tony Robbins discusses the "invisible forces" ...      1305
# 6          919  When two young Mormon missionaries knock on Ju...       992
# 7           46  Architect Joshua Prince-Ramus takes the audien...      1198
# 8          852  Philosopher Dan Dennett calls for religion -- ...      1485
# 9          900  Pastor Rick Warren, author of "The Purpose-Dri...      1262
# 10          79  Accepting his 2006 TED Prize, Cameron Sinclair...      1414
# ...

# %%
dfs[0:3]   ##印出列(橫向)
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
#
#      event   film_date  languages  main_speaker  \
# 0  TED2006  1140825600         60  Ken Robinson
# 1  TED2006  1140825600         43       Al Gore
# 2  TED2006  1140739200         26   David Pogue
#
#                                         name  num_speaker  \
# 0  Ken Robinson: Do schools kill creativity?            1
# 1       Al Gore: Averting the climate crisis            1
# 2              David Pogue: Simplicity sells            1
#
#                                              ratings  \
# 0  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 2  [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
#
# ...

# %%
dfs[0:500]
# Out:
#      comments                                        description  duration  \
# 0        4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1         265  With the same humor and humanity he exuded in ...       977
# 2         124  New York Times columnist David Pogue takes aim...      1286
# 3         200  In an emotionally charged talk, MacArthur-winn...      1116
# 4         593  You've never seen data presented like this. Wi...      1190
# 5         672  Tony Robbins discusses the "invisible forces" ...      1305
# 6         919  When two young Mormon missionaries knock on Ju...       992
# 7          46  Architect Joshua Prince-Ramus takes the audien...      1198
# 8         852  Philosopher Dan Dennett calls for religion -- ...      1485
# 9         900  Pastor Rick Warren, author of "The Purpose-Dri...      1262
# 10         79  Accepting his 2006 TED Prize, Cameron Sinclair...      1414
# ...

# %%
dfs.shape       #列,行 turple
# Out:
# (2550, 16)

# %%
dfs.shape[0]
# Out:
# 2550

# %%
dfs.columns      #取出第一行標籤
# Out:
# Index(['comments', 'description', 'duration', 'event', 'film_date',
#        'languages', 'main_speaker', 'name', 'num_speaker', 'ratings',
#        'related_talks', 'speaker_occupation', 'tags', 'title', 'url', 'views'],
#       dtype='object')

# %%
dfs.iloc[0]
# Out:
# comments                                                           4553
# description           Sir Ken Robinson makes an entertaining and pro...
# duration                                                           1164
# event                                                           TED2006
# film_date                                                    1140825600
# languages                                                            60
# main_speaker                                               Ken Robinson
# name                          Ken Robinson: Do schools kill creativity?
# num_speaker                                                           1
# ratings               [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# related_talks         [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...
# speaker_occupation                                      Author/educator
# tags                  ['children', 'creativity', 'culture', 'dance',...
# ...

# %%
dfs.iloc[:]     #全部列
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1          265  With the same humor and humanity he exuded in ...       977
# 2          124  New York Times columnist David Pogue takes aim...      1286
# 3          200  In an emotionally charged talk, MacArthur-winn...      1116
# 4          593  You've never seen data presented like this. Wi...      1190
# 5          672  Tony Robbins discusses the "invisible forces" ...      1305
# 6          919  When two young Mormon missionaries knock on Ju...       992
# 7           46  Architect Joshua Prince-Ramus takes the audien...      1198
# 8          852  Philosopher Dan Dennett calls for religion -- ...      1485
# 9          900  Pastor Rick Warren, author of "The Purpose-Dri...      1262
# 10          79  Accepting his 2006 TED Prize, Cameron Sinclair...      1414
# ...

# %%
dfs.iloc[2000:]    #2000列開始
# Out:
#       comments                                        description  duration  \
# 2000        75  Raised listening to his dad's old records, Joe...       388
# 2001       165  When writer Roxane Gay dubbed herself a "bad f...       688
# 2002        52  Book designer Chip Kidd knows all too well how...      1137
# 2003       198  Penicillin changed everything. Infections that...      1019
# 2004       186  Statistically, the least reliable part of the ...       929
# 2005        66  What do you learn when you sail around the wor...      1007
# 2006       227  With his signature resolve, former US Presiden...       996
# 2007       108  For the longest time, doctors basically ignore...       831
# 2008        78  In 2011, the US Armed Forces still had a ban o...       685
# 2009        42  Basketball is a fast-moving game of improvisat...       728
# 2010        59  Memory Banda’s life took a divergent path from...       758
# ...

# %%
dfs.iloc[50:100]    #顯示50~100行
# Out:
#     comments                                        description  duration  \
# 50        85  Robert Neuwirth, author of "Shadow Cities," fi...       843
# 51       499  Given $50 billion to spend, which would you so...      1001
# 52       371  With stunning photos and stories, National Geo...      1321
# 53        59  Photographer Phil Borges shows rarely seen ima...      1115
# 54       203  Speaking as both an astronomer and "a concerne...      1046
# 55       130  Author Robert Wright explains "non-zero-sumnes...      1151
# 56        47  Author Steven Johnson takes us on a 10-minute ...       603
# 57        91  In this deceptively casual talk, Charles Leadb...      1141
# 58       222  Two Pilobolus dancers perform "Symbiosis." Doe...       825
# 59       111  Writer and actor Anna Deavere Smith gives life...      1385
# 60        28  Inventor and MacArthur fellow Saul Griffith sh...       869
# 61        64  MIT professor Neil Gershenfeld talks about his...      1038
# ...

# %%
dfs.head(4)   #顯示前面4行
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  1140825600         60   Ken Robinson
# 1  TED2006  1140825600         43        Al Gore
# 2  TED2006  1140739200         26    David Pogue
# 3  TED2006  1140912000         35  Majora Carter
#
#                                         name  num_speaker  \
# 0  Ken Robinson: Do schools kill creativity?            1
# 1       Al Gore: Averting the climate crisis            1
# 2              David Pogue: Simplicity sells            1
# 3         Majora Carter: Greening the ghetto            1
#
# ...

# %%
dfs[["comments","description"]].iloc[2540:]     #列出comments description   列2540以後
# Out:
#       comments                                        description
# 2540        33  We've heard a lot of rhetoric lately suggestin...
# 2541        12  Physics doesn't just happen in a fancy lab -- ...
# 2542         3  In the century-old statues that occupy Cape To...
# 2543         7  What if you could know exactly how food or med...
# 2544        10  How can Africa, the home to some of the larges...
# 2545        17  Between 2008 and 2016, the United States depor...
# 2546         6  How can you study Mars without a spaceship? He...
# 2547        10  Science fiction visions of the future show us ...
# 2548        32  In an unmissable talk about race and politics ...
# 2549         8  With more than half of the world population li...

# %%
dfs["description"].str.contains("Sir")
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15       True
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 2520    False
# 2521    False
# 2522    False
# 2523    False
# 2524    False
# 2525    False
# 2526    False
# 2527    False
# 2528    False
# 2529    False
# 2530    False
# 2531    False
# 2532    False
# 2533    False
# 2534    False
# 2535    False
# 2536    False
# 2537    False
# 2538    False
# 2539    False
# 2540    False
# 2541    False
# 2542    False
# 2543    False
# 2544    False
# 2545    False
# 2546    False
# 2547    False
# 2548    False
# 2549    False
# ...

# %%
dfs[ dfs["description"].str.contains("Sir") ]  #dfs[複製上面的]
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 15         325  Violinist Sirena Huang gives a technically bri...      1481
# 54         203  Speaking as both an astronomer and "a concerne...      1046
# 692       1234  In this poignant, funny follow-up to his fable...      1008
# 833        473  In this talk from RSA Animate, Sir Ken Robinso...       700
# 1386       329  When most well-intentioned aid workers hear of...      1029
# 1502       634  Sir Ken Robinson outlines 3 principles crucial...      1151
# 1802        59  Sir Tim Berners-Lee invented the World Wide We...       403
# 1978        64  The founder of Sirius XM satellite radio, Mart...      1264
# 2192        61  Trust: How do you earn it? Banks use credit sc...       491
# 2503        20  How smart can our machines make us? Tom Gruber...       586
#
# ...

# %%
dfs[ dfs["description"].str.contains(r"\bSir\b") ]    #列出有Sir的字串  擷取較簡單
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 54         203  Speaking as both an astronomer and "a concerne...      1046
# 692       1234  In this poignant, funny follow-up to his fable...      1008
# 833        473  In this talk from RSA Animate, Sir Ken Robinso...       700
# 1502       634  Sir Ken Robinson outlines 3 principles crucial...      1151
# 1802        59  Sir Tim Berners-Lee invented the World Wide We...       403
#
#                     event   film_date  languages     main_speaker  \
# 0                 TED2006  1140825600         60     Ken Robinson
# 54         TEDGlobal 2005  1121299200         29      Martin Rees
# 692               TED2010  1265414400         57     Ken Robinson
# 833           RSA Animate  1287014400          0     Ken Robinson
# 1502  TED Talks Education  1366675200         43     Ken Robinson
# ...

# %%
#\b正規運算式  https://www.w3schools.com/jsref/jsref_regexp_begin.asp

# %%
dfs = dfs[ dfs[index].str.contains(r"\bSir\b") ]    #將舊資料取代

# %%
dfs.to_csv("result.csv", encoding = "utf-8",index = False ,index_label = False )  #把index表格刪除

# %%
#.to_csv     https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.to_csv.html
